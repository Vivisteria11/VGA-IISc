# %% [markdown]
# <a href="https://colab.research.google.com/github/Vivisteria11/VGA-IISc/blob/main/VGA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install flask langchain google-generativeai python-dotenv
# Out:
# Requirement already satisfied: flask in /usr/local/lib/python3.11/dist-packages (3.1.1)
# Requirement already satisfied: langchain in /usr/local/lib/python3.11/dist-packages (0.3.27)
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.11/dist-packages (0.8.5)
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from flask) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from flask) (8.2.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from flask) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from flask) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from flask) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from flask) (3.1.3)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.72)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.9)
# Requirement already satisfied: langsmith>=0.1.17 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.4.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.25.1)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.177.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.38.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.14.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core->google-generativeai) (1.70.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.17->langchain) (3.11.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (2025.7.14)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.3)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.74.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.1)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.1.1

# %%
# !pip install langchain_google_genai
# Out:
# Collecting langchain_google_genai
#   Downloading langchain_google_genai-2.1.8-py3-none-any.whl.metadata (7.0 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain_google_genai)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting google-ai-generativelanguage<0.7.0,>=0.6.18 (from langchain_google_genai)
#   Downloading google_ai_generativelanguage-0.6.18-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.68 in /usr/local/lib/python3.11/dist-packages (from langchain_google_genai) (0.3.72)
# Requirement already satisfied: pydantic<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain_google_genai) (2.11.7)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (2.25.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (5.29.5)
# Requirement already satisfied: langsmith>=0.3.45 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.68->langchain_google_genai) (0.4.8)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.68->langchain_google_genai) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.68->langchain_google_genai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.68->langchain_google_genai) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.68->langchain_google_genai) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.68->langchain_google_genai) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2->langchain_google_genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2->langchain_google_genai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2->langchain_google_genai) (0.4.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (2.32.3)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (1.74.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (1.71.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (4.9.1)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.68->langchain_google_genai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain_google_genai) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain_google_genai) (3.11.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain_google_genai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain_google_genai) (0.23.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain_google_genai) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain_google_genai) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain_google_genai) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain_google_genai) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain_google_genai) (0.16.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain_google_genai) (1.3.1)
# Downloading langchain_google_genai-2.1.8-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.8/47.8 kB 3.0 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading google_ai_generativelanguage-0.6.18-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 36.0 MB/s eta 0:00:00
# Installing collected packages: filetype, google-ai-generativelanguage, langchain_google_genai
#   Attempting uninstall: google-ai-generativelanguage
#     Found existing installation: google-ai-generativelanguage 0.6.15
#     Uninstalling google-ai-generativelanguage-0.6.15:
#       Successfully uninstalled google-ai-generativelanguage-0.6.15
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-generativeai 0.8.5 requires google-ai-generativelanguage==0.6.15, but you have google-ai-generativelanguage 0.6.18 which is incompatible.
# Successfully installed filetype-1.2.0 google-ai-generativelanguage-0.6.18 langchain_google_genai-2.1.8

# %%
import os
from google.colab import userdata

os.environ['GOOGLE_API_KEY']=userdata.get('GOOGLE_API_KEY')

# %%
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain.prompts import PromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
prompt = PromptTemplate.from_template(
    """
    You are a creative and compelling story  writer. Given a  specific topic and a concise  story description  generate:

    1. An elaborate 300 word storyline based on facts that must match the users description.Adapt the tone and style to match a playful, animated story.
    2. Character descriptions to blend based on the background scenes (Name , Traits,Appearance, Background scene).

    Format output as JSON like:
    {{
      "storyline": "...",
      "character_descriptions": [{{"name": "...", "traits": "...", "appearance": "...","background scene": "..."}}]
    }}

    Topic: {topic}
    Story Description: {description}
    """
)

# %%
prompt1 = PromptTemplate.from_template(
    """
    You are a creative and compelling story  writer. Given a  specific topic and a concise  story description  generate:

    1. An elaborate 300 word storyline based on facts that must match the users description.Adapt the tone and style to match a playful, animated story.
    2. Character descriptions to blend based on the background scenes (Name , Traits, Appearance, Background scene).

    Format output as JSON like:
    {{
      "storyline": "...",
      "character_descriptions": [{{"name": "...", "traits": "...", "appearance": "...","background scene": "..."}}]
    }}


    ---
    EXAMPLE
    Topic: The Great Acorn Heist
    Story Description: A clumsy squirrel and a clever raccoon team up to steal a giant acorn from a grumpy badger's garden.

    {{
      "storyline": "In the heart of Whispering Woods, Bartholomew, a badger with a prized, giant acorn, guards his garden with grumpy determination. But Nutty the squirrel, known more for his tumbles than his treasures, has a plan. He saw the acorn and knew it was the key to winning the annual Forest Feast. The only problem? He couldn't do it alone. He enlists the help of Rocket, a slick raccoon with a knack for gadgets and a love for shiny things. Their plan is a comical series of near-misses and slapstick moments. They try a catapult made of vines, a disguise as garden gnomes, and a tunnel that ends up in the wrong yard. Through their bumbling efforts, they accidentally flood Bartholomew’s garden, revealing the badger isn't grumpy, just lonely. The trio ends up sharing the giant acorn at the feast, forging an unlikely friendship. The story ends with them planning their next, less chaotic, adventure together.",
      "character_descriptions": [
        {{
          "name": "Nutty",
          "traits": "Ambitious, clumsy, optimistic, and slightly naive.",
          "appearance": "A small squirrel with a fluffy tail that's almost bigger than he is, wearing tiny, cracked aviator goggles.",
          "background_scene": "A bustling forest floor covered in autumn leaves or a messy treehouse filled with half-finished plans."
        }},
        {{
          "name": "Rocket",
          "traits": "Clever, resourceful, a bit of a show-off, and secretly caring.",
          "appearance": "A sleek, dark-grey raccoon with a confident smirk and a tool belt made of woven vines.",
          "background_scene": "A workshop inside a hollow log, filled with makeshift gadgets and shiny trinkets."
        }},
        {{
          "name": "Bartholomew",
          "traits": "Initially grumpy and possessive, but revealed to be lonely and seeking friendship.",
          "appearance": "A stout, round badger with thick spectacles perched on his nose and dirt stains on his paws from gardening.",
          "background_scene": "A perfectly manicured, fence-enclosed garden with a giant acorn on a pedestal."
        }}
      ]
    }}
    ---
    Topic: {topic}
    Story Description: {description}
    """
)

# %%
try:
  llm = ChatGoogleGenerativeAI(
  model="gemini-2.5-flash",
    temperature=0.7,

)
except Exception as e:
    print(f"Error initializing LLM. Check your API key. Error: {e}")
    llm = None

# %%
chain = (
    RunnablePassthrough()
    | prompt
    | llm
    | StrOutputParser()
)

# %%
input_data = {
    "topic": "Time Travel",
    "description": "A girl finds a watch that lets her rewind 24 hours and must fix a mistake."
}

result = chain.invoke(input_data)
print(result)
# Out:
# ```json
# {
#   "storyline": "Lily wasn't just any ten-year-old; she was a whirlwind of giggles, bright ideas, and the occasional magnificent mess. One sun-drenched afternoon, while rummaging through her eccentric Grandpa Gideon's attic, she stumbled upon a peculiar contraption. It was an antique pocket watch, brassy and intricate, with gears that seemed to hum with an unseen energy and a tiny, almost invisible button on its side. \"Ooh, shiny!\" Lily exclaimed, accidentally pressing the button. *WHOOSH!* The world blurred into a kaleidoscope of colors, and suddenly, she was back in her bedroom, exactly 24 hours earlier! Her pet hamster, Pip, was still safely in his cage, not scurrying under the sofa as he had been moments before. Lily gasped, her pigtails practically bouncing with excitement. \"Did I just... time travel?!\" she whispered. \n\nHer mission quickly became clear: fix yesterday's colossal mistake. Yesterday, in a burst of creative energy, Lily had tried to build a 'Supersonic Snack Delivery System' for Pip, which, instead of delivering snacks, had launched Pip himself into the living room, causing a domino effect of chaos involving a stack of delicate teacups and Grandpa Gideon's prize-winning petunias. Armed with the knowledge of her newfound 24-hour rewind power, Lily spent the 'replayed' day devising a new, safer snack system. She tried once, failed hilariously (Pip ended up in a lampshade), and *WHOOSH!* rewound again. The third time, Lily, with a determined glint in her eye, built a miniature zipline for the snacks, carefully securing Pip's cage. The day unfolded perfectly. No runaway hamster, no shattered teacups, and the petunias bloomed gloriously. Lily beamed, giving Pip a celebratory head scratch. The Chrono-Charm hummed softly on her wrist, a secret shared between a girl and her magical timepiece, ready for whatever playful predicaments tomorrow might bring.",
#   "character_descriptions": [
#     {
#       "name": "Lily",
#       "traits": "Energetic, imaginative, a bit clumsy, quick-thinking, caring, and incredibly curious.",
#       "appearance": "A tangle of bright ginger pigtails that seem to have a life of their own, wide, curious blue eyes that sparkle with mischief, and she's often sporting mismatched socks and a t-shirt with a whimsical design (like a rocket ship or a friendly monster).",
#       "background scene": "Her bedroom, a delightful explosion of color with half-finished art projects, stacks of adventure books, and a multi-level hamster cage, all bathed in the warm glow of afternoon sun streaming through a window."
#     },
#     {
#       "name": "Pip",
#       "traits": "Mischievous, adventurous, surprisingly fast, food-motivated, and a tiny escape artist.",
#       "appearance": "A small, fluffy ball of golden-brown fur with darting black eyes, constantly twitching whiskers, and ridiculously tiny, busy paws that can scurry with impressive speed.",
#       "background scene": "His multi-level hamster mansion, complete with tubes, a wheel, and a tiny food dish, or darting across the colorful living room carpet, leaving a trail of miniature chaos in his wake."
#     }
#   ]
# }
# ```

# %%
input_data = {
    "topic": "Buoyancy",
    "description": "A girl is having a rubber duck and a toy block next to her and is trying to learn the science concept from it."
}

result = chain.invoke(input_data)
print(result)
# Out:
# ```json
# {
#   "storyline": "Lily, with her bright, curious eyes, sat beside a bubbly, splashy tub. Her trusty sidekicks for this grand adventure were Quacky, the most cheerful rubber duck in all the land, and Bob, a sturdy wooden block painted a sunny yellow. \"Alright, team!\" Lily declared, wiggling her toes in the warm water. \"Today, we crack the mystery of the Great Float-or-Sink!\"\n\nFirst, Quacky took the plunge. *SPLASH!* He immediately bobbed right back up, giggling his rubbery squeak. \"Whee! I'm a natural-born floater!\" Quacky chirped, doing a little dance on the water's surface. Lily giggled, pushing him down gently. Whoosh! Up he popped again, as if an invisible spring was pushing him. \"Hmm,\" Lily pondered, \"Quacky is full of air, and air is super light! It helps him dance on top of the water.\"\n\nNext, it was Bob's turn. Lily carefully placed the wooden block on the water. *GENTLE PLOP!* Bob didn't sink to the bottom like a little rock; he floated too! But not quite like Quacky. Bob sat a bit deeper, looking very serious and composed. \"Oh, Bob!\" Lily exclaimed. \"You're a floater too, but you're not as bouncy as Quacky!\" She pressed Bob down. He resisted, then slowly, steadily, rose back up, a little less enthusiastically than Quacky.\n\n\"Aha!\" Lily's eyes lit up. \"Quacky is mostly air, making him super light for his size, so the water pushes him right up! Bob is wood, and wood is lighter than water, so he floats, but he's more solid, so he doesn't bounce as much.\" She grabbed a tiny, heavy pebble from a nearby pot. \"Now, for our grand finale!\" She dropped the pebble. *KER-PLUNK!* It zipped straight to the bottom. \"See?\" Lily announced triumphantly. \"The pebble is heavy for its size, so the water can't push it up! It sinks!\" Lily clapped her hands, feeling like a true scientist. Quacky bobbed his head in agreement, and Bob just sat there, reliably floating, proud of their shared discovery. Buoyancy: mystery solved, one bubbly splash at a time!",
#   "character_descriptions": [
#     {
#       "name": "Lily",
#       "traits": "Inquisitive, joyful, determined, imaginative.",
#       "appearance": "Bright, sparkling brown eyes, a cascade of messy pigtails tied with colorful ribbons, wearing cheerful, rainbow-striped overalls.",
#       "background scene": "Sitting excitedly beside a bubbly bathtub, surrounded by toys and curiosity."
#     },
#     {
#       "name": "Quacky",
#       "traits": "Cheerful, bouncy, a little mischievous, always ready for a splash.",
#       "appearance": "Vibrantly bright yellow, with a perky orange beak, tiny black dot eyes, and a perpetually wide, happy smile.",
#       "background scene": "Happily bobbing and squeaking on the surface of the bathtub water, doing little rubbery dances."
#     },
#     {
#       "name": "Bob",
#       "traits": "Sturdy, reliable, calm, a bit stoic, always floats steadily.",
#       "appearance": "Smooth, polished wooden cube, painted a warm, sunny yellow on one side, with perfectly square edges.",
#       "background scene": "Resting calmly beside the tub, then floating with dignified composure on the water's surface."
#     }
#   ]
# }
# ```

# %%
# 1. Install necessary libraries quietly
# !pip install flask pyngrok langchain-google-genai python-dotenv -q

# %%
import os
import json
from io import BytesIO
from PIL import Image

import google.generativeai as genai
from google.generativeai import types
from langchain.prompts import PromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.output_parsers import StrOutputParser




os.environ['GOOGLE_API_KEY']=userdata.get('GOOGLE_API_KEY')



story_prompt = PromptTemplate.from_template(
    """
    You are a creative and compelling story writer. Given a specific topic and a concise story description generate:

    1. An elaborate 300 word storyline based on facts that must match the users description.Adapt the tone and style to match a playful, animated story.
    2. Character descriptions to blend based on the background scenes (Name , Traits,Appearance, Background scene).

    Format output as a single, clean JSON object like:
    {{
      "storyline": "...",
      "character_descriptions": [{{"name": "...", "traits": "...", "appearance": "...","background_scene": "..."}}]
    }}

    Topic: {topic}
    Story Description: {description}
    """
)

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.7)
chain = story_prompt | llm | StrOutputParser()

# Input for the story
topic = "Gravity"
description = "An apple falling from a tree next to a boy  wearing spectacles."

# Invoke the chain and get the response text
response_text = chain.invoke({"topic": topic, "description": description})

# Extract the clean JSON from the response string
try:
    start = response_text.find("{")
    end = response_text.rfind("}") + 1
    story_data = json.loads(response_text[start:end])
    print("Story data generated successfully!")
except (json.JSONDecodeError, IndexError) as e:
    print(f"Failed to parse JSON from the first response: {e}")
    exit()



# Extract visual details from the generated story data
character = story_data["character_descriptions"][0]
appearance = character["appearance"]
background = character["background_scene"]

# Create a new, detailed prompt for the image generation model
contents = (
    f"Create a playful,  rendered image of a character described as: '{appearance}'. "
    f"The scene should be: '{background}'. The style must be vibrant and cheerful, suitable for a children's story, "
    "clearly showing the main subject from the story."
)
# Out:
# Story data generated successfully!
#
# Sending this prompt for image generation:
#  Create a playful,  rendered image of a character described as: 'Small for his age with messy brown hair that always seems to escape his slightly-too-big, round spectacles. Wears practical, slightly worn clothes suitable for orchard adventures, often with ink smudges from his creative bursts.'. The scene should be: 'Sitting cross-legged under the shade of a large apple tree, engrossed in his notebook, amidst dappled sunlight and the gentle hum of insects.'. The style must be vibrant and cheerful, suitable for a children's story, clearly showing the main subject from the story.
#
# An error occurred during image generation: 400 The requested combination of response modalities (TEXT) is not supported by the model. models/gemini-2.0-flash-preview-image-generation accepts the following combination of response modalities:
# * IMAGE, TEXT
#
# Please check that your API key has access to the 'gemini-2.0-flash-preview-image-generation' model.
# If the error persists, consider trying a standard model like 'image-generation-001'.

# %%
import os
import json
from io import BytesIO
from PIL import Image

from google import genai
from google.genai import types
from langchain.prompts import PromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.output_parsers import StrOutputParser

# Configure the API key
os.environ['GOOGLE_API_KEY'] = userdata.get('GOOGLE_API_KEY')

class StoryImageGenerator:
    def __init__(self):
        # Initialize Gemini clients
        self.genai_client = genai.Client(api_key=os.environ['GOOGLE_API_KEY'])

        # Story generation setup
        self.story_prompt = PromptTemplate.from_template(
            """
            You are a creative and compelling story writer. Given a specific topic, story description, and style, generate:

            1. An elaborate 300 word storyline based on facts that must match the users description. Adapt the tone and style to match the specified style: {style}.
            2. Character descriptions to blend based on the background scenes (Name, Traits, Appearance, Background scene).

            Format output as a single, clean JSON object like:
            {{
              "storyline": "...",
              "character_descriptions": [{{"name": "...", "traits": "...", "appearance": "...", "background_scene": "..."}}]
            }}

            Topic: {topic}
            Story Description: {description}
            Style: {style}
            """
        )

        self.llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash-exp", temperature=0.7)
        self.story_chain = self.story_prompt | self.llm | StrOutputParser()

    def generate_story_and_characters(self, topic, description, style):
        """Generate story and character descriptions"""
        print(f"Generating story for topic: {topic}")
        print(f"Description: {description}")
        print(f"Style: {style}")

        response_text = self.story_chain.invoke({
            "topic": topic,
            "description": description,
            "style": style
        })

        # Extract JSON from response
        try:
            start = response_text.find("{")
            end = response_text.rfind("}") + 1
            story_data = json.loads(response_text[start:end])

            # Display the JSON response
            print("\nGenerated Story and Character Data:")
            print(json.dumps(story_data, indent=2))

            return story_data
        except (json.JSONDecodeError, IndexError) as e:
            print(f"Failed to parse JSON: {e}")
            return None

    def generate_character_image(self, character, style, storyline):
        """Generate image using Gemini's native image generation API"""
        name = character["name"]
        appearance = character["appearance"]
        background = character["background_scene"]
        traits = character.get("traits", "")

        # Create detailed prompt for image generation
        contents = (
            f"Create a {style} illustration of a character named {name}. "
            f"Character appearance: {appearance}. "
            f"Character personality traits: {traits}. "
            f"Background setting: {background}. "
            f"The image should be in {style} style, high quality, detailed, and vibrant. "
            f"Make sure the character is the main focus with clear, engaging features suitable for the story context."
        )

        print(f"\nGenerating image for {name}...")

        try:
            # Use the correct Gemini image generation API
            response = self.genai_client.models.generate_content(
                model="gemini-2.0-flash-preview-image-generation",
                contents=contents,
                config=types.GenerateContentConfig(
                    response_modalities=['TEXT', 'IMAGE']
                )
            )

            # Process the response
            for part in response.candidates[0].content.parts:
                if part.text is not None:
                    pass  # Ignore text response
                elif part.inline_data is not None:
                    # Save the generated image
                    image = Image.open(BytesIO(part.inline_data.data))
                    filename = f"{name.replace(' ', '_').lower()}_{style.replace(' ', '_')}.png"
                    image.save(filename)
                    print(f"Image generated successfully for {name}")
                    image.show()  # Display the image
                    return filename

            print(f"No image data received for {name}")
            return None

        except Exception as e:
            print(f"Error generating image for {name}: {e}")
            return None

    def process_complete_story(self, topic, description, style):
        """Complete pipeline: story generation + image generation"""
        print(f"\nPROCESSING: {topic.upper()} - {style.upper()} STYLE")
        print("="*70)

        # Generate story and characters
        story_data = self.generate_story_and_characters(topic, description, style)
        if not story_data:
            return None

        # Generate images for each character
        print(f"\nGenerating images for {len(story_data['character_descriptions'])} character(s):")

        generated_images = []
        for i, character in enumerate(story_data["character_descriptions"]):
            image_file = self.generate_character_image(character, style, story_data["storyline"])
            if image_file:
                generated_images.append({
                    'character': character['name'],
                    'image_file': image_file,
                    'status': 'success'
                })
            else:
                generated_images.append({
                    'character': character['name'],
                    'image_file': None,
                    'status': 'failed'
                })

        return {
            'story_data': story_data,
            'generated_images': generated_images,
            'topic': topic,
            'style': style
        }

# Initialize the generator
generator = StoryImageGenerator()

print("STARTING GEMINI STORY-TO-IMAGE GENERATION TESTS...")

# TEST CASE 1: Realistic/Scientific Style
print("\nTEST CASE 1")
result1 = generator.process_complete_story(
    topic="Buoyancy",
    description="A curious girl is sitting next to a tub with a soft rubber duck and a toy square block seeing which will float or sink",
    style="realistic scientific illustration"
)

# TEST CASE 2: Fantasy/Magical Style
print("\nTEST CASE 2")
result2 = generator.process_complete_story(
      topic ="Gravity",
      description = "An apple falling from a tree next to a boy  wearing spectacles.",
      style="child friendly cartoon "
)

# TEST CASE 3: Cartoon/Children's Book Style
print("\nTEST CASE 3")
result3 = generator.process_complete_story(
    topic="Ocean Currents",
    description="Friendly sea creatures riding ocean currents in an underwater adventure",
    style="comic book "
)

# Final Results Summary
print("\nFINAL RESULTS SUMMARY")
print("="*50)

test_cases = [
    ("Bouyancy -realistic scientific illustration", result1),
    ("Gravity - child friendly cartoon  ", result2),
    ("Ocean Currents - comic book", result3)
]

for i, (test_name, result) in enumerate(test_cases, 1):
    print(f"\nTEST CASE {i}: {test_name}")
    if result:
        successful_images = [img for img in result['generated_images'] if img['status'] == 'success']
        failed_images = [img for img in result['generated_images'] if img['status'] == 'failed']

        print(f"Characters with images: {len(successful_images)}")
        print(f"Failed generations: {len(failed_images)}")

        for img_info in successful_images:
            print(f"  {img_info['character']}: {img_info['image_file']}")

        if failed_images:
            for img_info in failed_images:
                print(f"  {img_info['character']}: Failed to generate")
    else:
        print(f"COMPLETE FAILURE")

print("\nASSIGNMENT COMPLETED!")
print("Check your directory for generated image files")
# Out:
# STARTING GEMINI STORY-TO-IMAGE GENERATION TESTS...
#
# TEST CASE 1
#
# PROCESSING: BUOYANCY - REALISTIC SCIENTIFIC ILLUSTRATION STYLE
# ======================================================================
# Generating story for topic: Buoyancy
# Description: A curious girl is sitting next to a tub with a soft rubber duck and a toy square block seeing which will float or sink
# Style: realistic scientific illustration
#
# Generated Story and Character Data:
# {
#   "storyline": "A shaft of morning light illuminates Elara's makeshift laboratory: a ceramic bathtub filled halfway with tap water. Her brow furrowed in concentration, the eight-year-old meticulously observes two objects resting on the water's surface. To her left, a cheerfully yellow rubber duck bobs placidly. To her right, a significantly smaller, yet denser, wooden block stubbornly resists submersion. Elara's experiment is a study in buoyancy, a force she recently learned about from a well-worn science encyclopedia. She understands, at least conceptually, that buoyancy is an upward force exerted by a fluid that opposes the weight of an immersed object. The duck, despite its larger volume, displaces enough water to equal its weight, achieving equilibrium and floating merrily. The wooden block, while seemingly insignificant, presents a more complex scenario. Elara knows that wood is generally less dense than water, but the block's compact form hints at a higher density relative to its volume. She carefully pushes down on the block, noting the resistance and the amount of water displaced. She then releases it, watching it spring back up, demonstrating the buoyant force at play, even if the block is not fully submerged. Elara pulls out a small, waterproof notebook and meticulously records her observations, sketching diagrams of the water displacement and annotating the differing behaviors of the rubber duck and the wooden block. This is not just playtime; it's a scientific investigation, fueled by curiosity and a burgeoning understanding of the physical world.",
#   "character_descriptions": [
#     {
#       "name": "Elara Vance",
#       "traits": "Curious, meticulous, observant, analytical, inquisitive, patient",
#       "appearance": "Eight years old, with bright, intelligent eyes and a smattering of freckles across her nose. She has long, auburn hair pulled back into a loose braid. She wears a simple, practical blue dress and sturdy sandals, suitable for scientific explorations.",
#       "background_scene": "Sitting cross-legged beside a ceramic bathtub, partially filled with water. The bathroom is brightly lit by morning sunlight streaming through a window. Scattered around her are a small waterproof notebook, a pencil, a rubber duck, and a wooden block."
#     }
#   ]
# }
#
# Generating images for 1 character(s):
#
# Generating image for Elara Vance...
# Image generated successfully for Elara Vance
#
# TEST CASE 2
#
# PROCESSING: GRAVITY - CHILD FRIENDLY CARTOON  STYLE
# ======================================================================
# Generating story for topic: Gravity
# Description: An apple falling from a tree next to a boy  wearing spectacles.
# Style: child friendly cartoon
#
# Generated Story and Character Data:
# {
#   "storyline": "Once upon a time, in a sunny orchard filled with giggling apple trees, lived a curious little boy named Newton. Newton loved to read, especially about the stars and how the world worked! He had a big, bright smile and even bigger spectacles perched on his nose, which made him look extra smart. One warm afternoon, Newton was sitting under his favorite apple tree, lost in a book about flying squirrels. Suddenly, *plop!* An apple, as red and shiny as a ruby, bonked him gently on the head! Newton wasn't hurt, but he was puzzled. Why did the apple fall *down* instead of up, or sideways? He looked up at the tree, then back at the apple. Hmmm, this was a mystery! He imagined the apple floating away like a balloon, then giggled. That would be silly! The ground seemed to be pulling the apple down. He decided to call it 'Gravity' a special invisible force that pulls everything towards the ground. He imagined Gravity as a friendly, big, blue bear hugging everything gently. Newton smiled, he knew he was on to something BIG! He couldn't wait to learn more about this amazing 'Gravity' and how it kept everything from floating away into space!",
#   "character_descriptions": [
#     {
#       "name": "Newton",
#       "traits": "Curious, intelligent, imaginative, a bit clumsy",
#       "appearance": "Small boy with messy brown hair, large round spectacles, wearing a blue and white striped shirt and overalls. Always has a book nearby.",
#       "background_scene": "Sitting under a large, green apple tree in a sunny orchard. Apples are scattered around him on the grass. A gentle breeze rustles the leaves."
#     },
#     {
#       "name": "Gravity (Imagined)",
#       "traits": "Friendly, gentle, strong, reliable",
#       "appearance": "A large, fluffy blue bear with a kind smile. He has small wings on his back, but he never flies, preferring to stay grounded.",
#       "background_scene": "Envisioned floating around Newton, hugging the apple tree and the ground, creating a soft, blue glow."
#     },
#     {
#       "name": "Red Apple (Roger)",
#       "traits": "Happy, Juicy, a bit cheeky",
#       "appearance": "A Red, shiny apple with a small leaf on the top",
#       "background_scene": "Hanging on the apple tree near Newton, then falling down to the ground."
#     }
#   ]
# }
#
# Generating images for 3 character(s):
#
# Generating image for Newton...
# Image generated successfully for Newton
#
# Generating image for Gravity (Imagined)...
# Image generated successfully for Gravity (Imagined)
#
# Generating image for Red Apple (Roger)...
# Image generated successfully for Red Apple (Roger)
#
# TEST CASE 3
#
# PROCESSING: OCEAN CURRENTS - COMIC BOOK  STYLE
# ======================================================================
# Generating story for topic: Ocean Currents
# Description: Friendly sea creatures riding ocean currents in an underwater adventure
# Style: comic book
#
# Generated Story and Character Data:
# {
#   "storyline": "SPLASH! Coralina, a spunky clownfish with a thirst for adventure, stared out from her anemone home. Today was the day! She was finally old enough to ride the legendary East Australian Current, a super-highway of the sea! KA-THOOM! Suddenly, Barnaby, a burly but lovable sea turtle with barnacles for buddies, lumbered into view. \"Ready for the ride, kiddo?\" he boomed. Coralina nodded, her fins trembling with excitement. ZOOM! They were off! The current propelled them past shimmering schools of fish and bizarre, bioluminescent jellyfish. They met Zephyr, a sleek dolphin with a knack for navigating the swirling eddies of the current. \"Watch out for the Sargasso Sea, mates!\" Zephyr warned, pointing his snout towards a murky patch ahead. \"It's full of grumpy anglerfish and tangled seaweed!\" UH-OH! A colossal wall of Sargassum weed loomed before them. Coralina, using her small size and surprising agility, zipped through the weeds, creating a path for Barnaby. Zephyr, with his sonar, guided them through the inky darkness. Finally, they burst free, emerging into a dazzling coral reef, vibrant and teeming with life! They had conquered the Sargasso and proven that even the smallest fish could ride the biggest currents!",
#   "character_descriptions": [
#     {
#       "name": "Coralina",
#       "traits": "Spunky, adventurous, agile, determined, friendly",
#       "appearance": "Clownfish with bright orange and white stripes, large expressive eyes, small but powerful fins",
#       "background_scene": "Anemone home, vibrant coral reef"
#     },
#     {
#       "name": "Barnaby",
#       "traits": "Burly, lovable, reliable, strong, slightly clumsy",
#       "appearance": "Large sea turtle with a mossy green shell covered in barnacles, wise and kind eyes",
#       "background_scene": "Open ocean, riding the East Australian Current"
#     },
#     {
#       "name": "Zephyr",
#       "traits": "Sleek, intelligent, navigational expert, helpful, cautious",
#       "appearance": "Streamlined dolphin with smooth grey skin, keen eyes, a distinctive scar near his blowhole",
#       "background_scene": "Eddies and swirls of the East Australian Current, murky Sargasso Sea"
#     }
#   ]
# }
#
# Generating images for 3 character(s):
#
# Generating image for Coralina...
# Image generated successfully for Coralina
#
# Generating image for Barnaby...
# Image generated successfully for Barnaby
#
# Generating image for Zephyr...
# Image generated successfully for Zephyr
#
# FINAL RESULTS SUMMARY
# ==================================================
#
# TEST CASE 1: Bouyancy -realistic scientific illustration
# Characters with images: 1
# Failed generations: 0
#   Elara Vance: elara_vance_realistic_scientific_illustration.png
#
# TEST CASE 2: Gravity - child friendly cartoon
# Characters with images: 3
# Failed generations: 0
#   Newton: newton_child_friendly_cartoon_.png
#   Gravity (Imagined): gravity_(imagined)_child_friendly_cartoon_.png
#   Red Apple (Roger): red_apple_(roger)_child_friendly_cartoon_.png
#
# TEST CASE 3: Ocean Currents - comic book
# Characters with images: 3
# Failed generations: 0
#   Coralina: coralina_comic_book_.png
#   Barnaby: barnaby_comic_book_.png
#   Zephyr: zephyr_comic_book_.png
#
# ASSIGNMENT COMPLETED!
# Check your directory for generated image files

# %%
import os
import json
from io import BytesIO
from PIL import Image

from google import genai
from google.genai import types
from langchain.prompts import PromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.output_parsers import StrOutputParser

# Configure the API key
os.environ['GOOGLE_API_KEY'] = userdata.get('GOOGLE_API_KEY')

class StoryImageGenerator:
    def __init__(self):
        # Initialize Gemini clients
        self.genai_client = genai.Client(api_key=os.environ['GOOGLE_API_KEY'])

        # Story generation setup
        self.story_prompt = PromptTemplate.from_template(
            """
            You are a creative and compelling story writer. Given a specific topic and story description, generate:

            1. An elaborate 300 word storyline based on facts that must match the users description.
            2. Character descriptions to blend based on the background scenes (Name, Traits, Appearance, Background scene).

            Format output as a single, clean JSON object like:
            {{
              "storyline": "...",
              "character_descriptions": [{{"name": "...", "traits": "...", "appearance": "...", "background_scene": "..."}}]
            }}

            Topic: {topic}
            Story Description: {description}
            """
        )

        self.llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash-exp", temperature=0.7)
        self.story_chain = self.story_prompt | self.llm | StrOutputParser()

    def generate_story_and_characters(self, topic, description):
        """Generate story and character descriptions"""
        print(f"Generating story for topic: {topic}")
        print(f"Description: {description}")

        response_text = self.story_chain.invoke({
            "topic": topic,
            "description": description
        })

        # Extract JSON from response
        try:
            start = response_text.find("{")
            end = response_text.rfind("}") + 1
            story_data = json.loads(response_text[start:end])

            # Display the JSON response
            print("\nGenerated Story and Character Data:")
            print(json.dumps(story_data, indent=2))

            return story_data
        except (json.JSONDecodeError, IndexError) as e:
            print(f"Failed to parse JSON: {e}")
            return None

    def generate_character_image(self, character, storyline):
        """Generate image using Gemini's native image generation API"""
        name = character["name"]
        appearance = character["appearance"]
        background = character["background_scene"]
        traits = character.get("traits", "")

        # Create detailed prompt for image generation
        contents = (
            f"Create a high-quality illustration of a character named {name}. "
            f"Character appearance: {appearance}. "
            f"Character personality traits: {traits}. "
            f"Background setting: {background}. "
            f"The image should be detailed, vibrant, and engaging. "
            f"Make sure the character is the main focus with clear features suitable for the story context."
        )

        print(f"\nGenerating image for {name}...")

        try:
            # Use the correct Gemini image generation API
            response = self.genai_client.models.generate_content(
                model="gemini-2.0-flash-preview-image-generation",
                contents=contents,
                config=types.GenerateContentConfig(
                    response_modalities=['TEXT', 'IMAGE']
                )
            )

            # Process the response
            for part in response.candidates[0].content.parts:
                if part.text is not None:
                    pass  # Ignore text response
                elif part.inline_data is not None:
                    # Save the generated image
                    image = Image.open(BytesIO(part.inline_data.data))
                    filename = f"{name.replace(' ', '_').lower()}.png"
                    image.save(filename)
                    print(f"Image generated successfully for {name}")
                    image.show()  # Display the image
                    return filename

            print(f"No image data received for {name}")
            return None

        except Exception as e:
            print(f"Error generating image for {name}: {e}")
            return None

    def process_complete_story(self, topic, description):
        """Complete pipeline: story generation + image generation"""
        print(f"\nPROCESSING: {topic.upper()}")
        print("="*70)

        # Generate story and characters
        story_data = self.generate_story_and_characters(topic, description)
        if not story_data:
            return None

        # Generate images for each character
        print(f"\nGenerating images for {len(story_data['character_descriptions'])} character(s):")

        generated_images = []
        for i, character in enumerate(story_data["character_descriptions"]):
            image_file = self.generate_character_image(character, story_data["storyline"])
            if image_file:
                generated_images.append({
                    'character': character['name'],
                    'image_file': image_file,
                    'status': 'success'
                })
            else:
                generated_images.append({
                    'character': character['name'],
                    'image_file': None,
                    'status': 'failed'
                })

        return {
            'story_data': story_data,
            'generated_images': generated_images,
            'topic': topic
        }

# Initialize the generator
generator = StoryImageGenerator()

print("STARTING GEMINI STORY-TO-IMAGE GENERATION TESTS...")

# TEST CASE 1: Buoyancy
print("\nTEST CASE 1")
result1 = generator.process_complete_story(
    topic="Buoyancy",
    description="A curious girl is sitting next to a tub with a soft rubber duck and a toy square block seeing which will float or sink"
)

# TEST CASE 2: Gravity
print("\nTEST CASE 2")
result2 = generator.process_complete_story(
    topic="Gravity",
    description="An apple falling from a tree next to a boy wearing spectacles"
)

# Final Results Summary
print("\nFINAL RESULTS SUMMARY")
print("="*50)

test_cases = [
    ("Buoyancy", result1),
    ("Gravity", result2)
]

for i, (test_name, result) in enumerate(test_cases, 1):
    print(f"\nTEST CASE {i}: {test_name}")
    if result:
        successful_images = [img for img in result['generated_images'] if img['status'] == 'success']
        failed_images = [img for img in result['generated_images'] if img['status'] == 'failed']

        print(f"Characters with images: {len(successful_images)}")
        print(f"Failed generations: {len(failed_images)}")

        for img_info in successful_images:
            print(f"  {img_info['character']}: {img_info['image_file']}")

        if failed_images:
            for img_info in failed_images:
                print(f"  {img_info['character']}: Failed to generate")
    else:
        print(f"COMPLETE FAILURE")

print("\nASSIGNMENT COMPLETED!")
print("Check your directory for generated image files")
# Out:
# STARTING GEMINI STORY-TO-IMAGE GENERATION TESTS...
#
# TEST CASE 1
#
# PROCESSING: BUOYANCY
# ======================================================================
# Generating story for topic: Buoyancy
# Description: A curious girl is sitting next to a tub with a soft rubber duck and a toy square block seeing which will float or sink
#
# Generated Story and Character Data:
# {
#   "storyline": "Lila, a bright-eyed seven-year-old with a perpetual smudge of crayon on her cheek, perched on the edge of the old clawfoot bathtub. The tub, filled halfway with tepid water, was her laboratory for the afternoon. Her tools: a cheerful yellow rubber duck, worn smooth from countless baths, and a sturdy, brightly colored square block, a hand-me-down from her older brother. Lila's brow furrowed in concentration as she held the duck aloft. 'Operation Float or Sink,' she murmured to Mr. Snuggles, her stuffed bear propped against the faucet. She knew, deep down, that the duck would float. It always did. But the block\u2026 that was the real mystery. She remembered her dad explaining something about displacement and density, words that swam around in her head like confused goldfish. \n\nWith a deliberate slowness, she lowered the duck into the water. As expected, it bobbed merrily, its painted eyes seeming to wink. A triumphant grin spread across Lila's face. Next, the block. She paused, a moment of genuine scientific anticipation hanging in the air. Down it went, and with a gentle 'thunk,' settled at the bottom of the tub. Lila leaned closer, her nose practically touching the water. The block remained stubbornly submerged. She poked it tentatively with a finger. Still at the bottom. 'Density wins,' she declared, a hint of disappointment in her voice. But then, a new idea sparked in her eyes. What if she tried something else? She scurried off to find a spoon, then began scooping water out of the tub to see if the block would come up, concluding the more water that was in the tub, the more the block would sink.",
#   "character_descriptions": [
#     {
#       "name": "Lila",
#       "traits": "Curious, inquisitive, bright, persistent, a bit messy.",
#       "appearance": "Seven years old, with bright, curious eyes and a dusting of freckles across her nose. She has tangled brown hair pulled back in a messy ponytail. Wears a slightly oversized t-shirt with a picture of a rocket ship and mismatched socks.",
#       "background_scene": "Bathroom with an old clawfoot tub, slightly chipped paint, and colorful bath toys scattered around. A window lets in soft afternoon light."
#     },
#     {
#       "name": "Mr. Snuggles",
#       "traits": "Silent, supportive, well-loved, slightly threadbare.",
#       "appearance": "A brown teddy bear with one missing button eye and a patch sewn onto his tummy. He's soft and cuddly, showing signs of much affection.",
#       "background_scene": "Perched precariously on the faucet of the clawfoot tub, observing Lila's experiment with unwavering attention."
#     }
#   ]
# }
#
# Generating images for 2 character(s):
#
# Generating image for Lila...
# Image generated successfully for Lila
#
# Generating image for Mr. Snuggles...
# Image generated successfully for Mr. Snuggles
#
# TEST CASE 2
#
# PROCESSING: GRAVITY
# ======================================================================
# Generating story for topic: Gravity
# Description: An apple falling from a tree next to a boy wearing spectacles
#
# Generated Story and Character Data:
# {
#   "storyline": "The late afternoon sun cast long shadows across the orchard, painting the dew-kissed grass in hues of gold and amber. Ten-year-old Elias, perched precariously on a gnarled root of the ancient apple tree, adjusted his spectacles, the lenses magnifying the already vibrant world around him. He was engrossed in a dog-eared copy of 'Principia Mathematica,' a book far too advanced for his age, yet one he devoured with insatiable curiosity. He mumbled equations under his breath, oblivious to the gentle breeze rustling the leaves above. A particularly ripe apple, swollen with the season's bounty, strained against its stem. The connection weakened, and with a soft 'thud,' the apple detached. It plummeted earthward, accelerating as it fell, a flash of crimson against the green canopy. Elias, jolted from his intellectual pursuits by the sound, looked up just in time to see the apple land squarely on the open page of his book. A smudge of apple juice bloomed across a diagram of planetary motion. Initially annoyed, Elias stared at the apple, then back at his book. A slow smile spread across his face. The falling apple, a simple, everyday occurrence, suddenly seemed to hold a profound secret. He picked it up, turning it over in his hands. Could this force, this invisible hand that pulled the apple to the ground, be the same force that kept the moon in orbit? The question sparked a fire in his young mind, a fire that would burn for decades to come, fueling his relentless pursuit of understanding the universe's hidden laws.",
#   "character_descriptions": [
#     {
#       "name": "Elias Thorne",
#       "traits": "Intensely curious, bookish, slightly clumsy, precocious, thoughtful",
#       "appearance": "A slender boy with a mop of unruly brown hair that perpetually falls into his eyes. He wears round, wire-rimmed spectacles that are slightly too large for his face. His clothes are usually rumpled and stained with ink or fruit juice. He has a perpetually thoughtful expression and carries a worn leather satchel filled with books.",
#       "background_scene": "An old apple orchard in late afternoon, dappled sunlight filtering through the leaves. The air is filled with the scent of ripe apples and damp earth. A large, gnarled apple tree dominates the scene, its branches laden with fruit."
#     }
#   ]
# }
#
# Generating images for 1 character(s):
#
# Generating image for Elias Thorne...
# Image generated successfully for Elias Thorne
#
# FINAL RESULTS SUMMARY
# ==================================================
#
# TEST CASE 1: Buoyancy
# Characters with images: 2
# Failed generations: 0
#   Lila: lila.png
#   Mr. Snuggles: mr._snuggles.png
#
# TEST CASE 2: Gravity
# Characters with images: 1
# Failed generations: 0
#   Elias Thorne: elias_thorne.png
#
# ASSIGNMENT COMPLETED!
# Check your directory for generated image files
